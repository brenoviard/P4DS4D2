# %% [markdown]
# # Usando Jupyter Notebook

# %% [markdown]
# ## Trabalhando com estilos

# %% [markdown]
# # Inserindo gráficos e outras imagens

# %%
# %matplotlib inline

# %% [markdown]
# ## Carregando exemplos de sites

# %%
# %Load https://matplotlib.or/_downloads/pyplot_text.py

"""
===========
Pyplot Text
===========

"""

import numpy as np
import matplotlib.pyplot as plt


np.random.seed(19680801)


mu, sigma = 100, 15
x = mu + sigma * np.random.randn(10000)

n,bis,pacthes = plt.hist(x, 50, density=True, facecolor='b', alpha=0.45)

plt.xlabel('Smarts')
plt.ylabel('Probability')
plt.title('Histogram of IQ')
plt.text(60, .025, r'$\mu=100,\ \sigma=15$')
plt.axis([40, 160, 0, 0.03])
plt.grid(True)
plt.show()

# %%
from IPython.display import Image
Embed = Image(
    'http://blog.johnmuellerbooks.com/'+
    'wp-content/uploads/2015/04/Layer-Hens.jpg')
Embed
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_14256\3288313481.py in <module>
#       1 from IPython.display import Image
# ----> 2 Embed = Image(
#       3     'http://blog.johnmuellerbooks.com/'+
#       4     'wp-content/uploads/2015/04/Layer-Hens.jpg')
#       5 Embed
#
# ~\anaconda3\lib\site-packages\IPython\core\display.py in __init__(self, data, url, filename, format, embed, width, height, retina, unconfined, metadata)
#    1229         self.retina = retina
#    1230         self.unconfined = unconfined
# -> 1231         super(Image, self).__init__(data=data, url=url, filename=filename,
#    1232                 metadata=metadata)
#    1233
#
# ~\anaconda3\lib\site-packages\IPython\core\display.py in __init__(self, data, url, filename, metadata)
#     635             self.metadata = {}
#     636
# --> 637         self.reload()
# ...

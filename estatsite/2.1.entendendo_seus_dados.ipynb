# %%
import pandas as pd
df = pd.read_csv('Iris.csv')

# %%
df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
df.plot(kind='hist', x='SepalLengthCm', y='SepalWidthCm')
# Out:
# <Axes: ylabel='Frequency'>

# %%
df.plot(kind='scatter', x='SepalLengthCm', y='SepalWidthCm',color='Green',title='Gráfico de Dispersão')
# Out:
# <Axes: title={'center': 'Gráfico de Dispersão'}, xlabel='SepalLengthCm', ylabel='SepalWidthCm'>

# %% [markdown]
# ## Entendendo seus dados em Python

# %%
import pandas as pd
#criando o dataframe

dtf = pd.DataFrame({'a': pd.date_range('20130102', periods =7),
                  'b':pd.Series([1,2,3,'NaN',5,6,7], index = list(range(7)),dtype='float32'),
                  'c':pd.Categorical(['azul','azul','verde','verde','cinza','marrom','azul'])})

# %%
dtf.head(3)
# Out:
#            a    b      c
# 0 2013-01-02  1.0   azul
# 1 2013-01-03  2.0   azul
# 2 2013-01-04  3.0  verde

# %%
dtf.tail(3)
# Out:
#            a    b       c
# 4 2013-01-06  5.0   cinza
# 5 2013-01-07  6.0  marrom
# 6 2013-01-08  7.0    azul

# %%
dtf.dtypes
# Out:
# a    datetime64[ns]
# b           float32
# c          category
# dtype: object

# %%
dtf.columns
# Out:
# Index(['a', 'b', 'c'], dtype='object')

# %%
list(dtf.columns.values)
# Out:
# ['a', 'b', 'c']

# %%
dtf.apply(lambda x:sum(x.isnull()),axis=0)
# lambda cria um parametrto para outra funçã
# nesse caso lambda x soma quantidades se encontrar valores nulos dentro do dataframe
# Out:
# a    0
# b    1
# c    0
# dtype: int64

# %%
#modificar a ordem apresentada

dtf.sort_index(axis=1)
# Out:
#            a    b       c
# 0 2013-01-02  1.0    azul
# 1 2013-01-03  2.0    azul
# 2 2013-01-04  3.0   verde
# 3 2013-01-05  NaN   verde
# 4 2013-01-06  5.0   cinza
# 5 2013-01-07  6.0  marrom
# 6 2013-01-08  7.0    azul

# %%
#ordna  linhas de acordo com a coluna B em ordem descrescente
dtf.sort_values(by='b', ascending=False)#descending não existe
# Out:
#            a    b       c
# 6 2013-01-08  7.0    azul
# 5 2013-01-07  6.0  marrom
# 4 2013-01-06  5.0   cinza
# 2 2013-01-04  3.0   verde
# 1 2013-01-03  2.0    azul
# 0 2013-01-02  1.0    azul
# 3 2013-01-05  NaN   verde

# %%
dtf[2:4]#drlrviona da linha 2 a  4
# Out:
#            a    b      c
# 2 2013-01-04  3.0  verde
# 3 2013-01-05  NaN  verde

# %%
dtf['b']#seleciona apenas a coluna b
# Out:
# 0    1.0
# 1    2.0
# 2    3.0
# 3    NaN
# 4    5.0
# 5    6.0
# 6    7.0
# Name: b, dtype: float32

# %%
#selecionar linhas de acordo com uma condição
dtf.loc[(dtf['c']=='azul')]
# Out:
#            a    b     c
# 0 2013-01-02  1.0  azul
# 1 2013-01-03  2.0  azul
# 6 2013-01-08  7.0  azul

# %%
#selecionar quando a coluna c for azul e menor que 2
dtf.loc[(dtf['c']=='azul')& (dtf['b']<2)]
# Out:
#            a    b     c
# 0 2013-01-02  1.0  azul

# %%
#selecionar quando a coluna c for azul e menor que 8
dtf.loc[(dtf['c']==azul)&(dtf['b']<)]
